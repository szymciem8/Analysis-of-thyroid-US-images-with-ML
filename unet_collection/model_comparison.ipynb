# %%
from utils import *

# %%
from keras_unet_collection import models, losses

# %%
image_input_shape = (384, 384, 1)
filter_num = [64, 128, 256, 512]

# %%
# model = get_model('unet_2d', image_input_shape, [32, 64, 128, 256, 512, 1024])

model = models.unet_2d((320, 320, 1), [32, 64, 128, 256, 512, 1024], n_labels=1, output_activation='Sigmoid', stack_num_down=4, stack_num_up=4)

# %%
model.summary()
# Out:
# Model: "unet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# unet_down0_0 (Conv2D)           (None, 320, 320, 32) 320         input_8[0][0]
# __________________________________________________________________________________________________
# unet_down0_0_activation (ReLU)  (None, 320, 320, 32) 0           unet_down0_0[0][0]
# __________________________________________________________________________________________________
# unet_down0_1 (Conv2D)           (None, 320, 320, 32) 9248        unet_down0_0_activation[0][0]
# __________________________________________________________________________________________________
# unet_down0_1_activation (ReLU)  (None, 320, 320, 32) 0           unet_down0_1[0][0]
# __________________________________________________________________________________________________
# unet_down0_2 (Conv2D)           (None, 320, 320, 32) 9248        unet_down0_1_activation[0][0]
# __________________________________________________________________________________________________
# unet_down0_2_activation (ReLU)  (None, 320, 320, 32) 0           unet_down0_2[0][0]
# __________________________________________________________________________________________________
# unet_down0_3 (Conv2D)           (None, 320, 320, 32) 9248        unet_down0_2_activation[0][0]
# __________________________________________________________________________________________________
# unet_down0_3_activation (ReLU)  (None, 320, 320, 32) 0           unet_down0_3[0][0]
# __________________________________________________________________________________________________
# unet_down1_encode_maxpool (MaxP (None, 160, 160, 32) 0           unet_down0_3_activation[0][0]
# __________________________________________________________________________________________________
# unet_down1_conv_0 (Conv2D)      (None, 160, 160, 64) 18496       unet_down1_encode_maxpool[0][0]
# __________________________________________________________________________________________________
# unet_down1_conv_0_activation (R (None, 160, 160, 64) 0           unet_down1_conv_0[0][0]
# __________________________________________________________________________________________________
# unet_down1_conv_1 (Conv2D)      (None, 160, 160, 64) 36928       unet_down1_conv_0_activation[0][0
# __________________________________________________________________________________________________
# unet_down1_conv_1_activation (R (None, 160, 160, 64) 0           unet_down1_conv_1[0][0]
# __________________________________________________________________________________________________
# unet_down1_conv_2 (Conv2D)      (None, 160, 160, 64) 36928       unet_down1_conv_1_activation[0][0
# __________________________________________________________________________________________________
# unet_down1_conv_2_activation (R (None, 160, 160, 64) 0           unet_down1_conv_2[0][0]
# __________________________________________________________________________________________________
# unet_down1_conv_3 (Conv2D)      (None, 160, 160, 64) 36928       unet_down1_conv_2_activation[0][0
# __________________________________________________________________________________________________
# unet_down1_conv_3_activation (R (None, 160, 160, 64) 0           unet_down1_conv_3[0][0]
# __________________________________________________________________________________________________
# unet_down2_encode_maxpool (MaxP (None, 80, 80, 64)   0           unet_down1_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_down2_conv_0 (Conv2D)      (None, 80, 80, 128)  73856       unet_down2_encode_maxpool[0][0]
# __________________________________________________________________________________________________
# unet_down2_conv_0_activation (R (None, 80, 80, 128)  0           unet_down2_conv_0[0][0]
# __________________________________________________________________________________________________
# unet_down2_conv_1 (Conv2D)      (None, 80, 80, 128)  147584      unet_down2_conv_0_activation[0][0
# __________________________________________________________________________________________________
# unet_down2_conv_1_activation (R (None, 80, 80, 128)  0           unet_down2_conv_1[0][0]
# __________________________________________________________________________________________________
# unet_down2_conv_2 (Conv2D)      (None, 80, 80, 128)  147584      unet_down2_conv_1_activation[0][0
# __________________________________________________________________________________________________
# unet_down2_conv_2_activation (R (None, 80, 80, 128)  0           unet_down2_conv_2[0][0]
# __________________________________________________________________________________________________
# unet_down2_conv_3 (Conv2D)      (None, 80, 80, 128)  147584      unet_down2_conv_2_activation[0][0
# __________________________________________________________________________________________________
# unet_down2_conv_3_activation (R (None, 80, 80, 128)  0           unet_down2_conv_3[0][0]
# __________________________________________________________________________________________________
# unet_down3_encode_maxpool (MaxP (None, 40, 40, 128)  0           unet_down2_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_down3_conv_0 (Conv2D)      (None, 40, 40, 256)  295168      unet_down3_encode_maxpool[0][0]
# __________________________________________________________________________________________________
# unet_down3_conv_0_activation (R (None, 40, 40, 256)  0           unet_down3_conv_0[0][0]
# __________________________________________________________________________________________________
# unet_down3_conv_1 (Conv2D)      (None, 40, 40, 256)  590080      unet_down3_conv_0_activation[0][0
# __________________________________________________________________________________________________
# unet_down3_conv_1_activation (R (None, 40, 40, 256)  0           unet_down3_conv_1[0][0]
# __________________________________________________________________________________________________
# unet_down3_conv_2 (Conv2D)      (None, 40, 40, 256)  590080      unet_down3_conv_1_activation[0][0
# __________________________________________________________________________________________________
# unet_down3_conv_2_activation (R (None, 40, 40, 256)  0           unet_down3_conv_2[0][0]
# __________________________________________________________________________________________________
# unet_down3_conv_3 (Conv2D)      (None, 40, 40, 256)  590080      unet_down3_conv_2_activation[0][0
# __________________________________________________________________________________________________
# unet_down3_conv_3_activation (R (None, 40, 40, 256)  0           unet_down3_conv_3[0][0]
# __________________________________________________________________________________________________
# unet_down4_encode_maxpool (MaxP (None, 20, 20, 256)  0           unet_down3_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_down4_conv_0 (Conv2D)      (None, 20, 20, 512)  1180160     unet_down4_encode_maxpool[0][0]
# __________________________________________________________________________________________________
# unet_down4_conv_0_activation (R (None, 20, 20, 512)  0           unet_down4_conv_0[0][0]
# __________________________________________________________________________________________________
# unet_down4_conv_1 (Conv2D)      (None, 20, 20, 512)  2359808     unet_down4_conv_0_activation[0][0
# __________________________________________________________________________________________________
# unet_down4_conv_1_activation (R (None, 20, 20, 512)  0           unet_down4_conv_1[0][0]
# __________________________________________________________________________________________________
# unet_down4_conv_2 (Conv2D)      (None, 20, 20, 512)  2359808     unet_down4_conv_1_activation[0][0
# __________________________________________________________________________________________________
# unet_down4_conv_2_activation (R (None, 20, 20, 512)  0           unet_down4_conv_2[0][0]
# __________________________________________________________________________________________________
# unet_down4_conv_3 (Conv2D)      (None, 20, 20, 512)  2359808     unet_down4_conv_2_activation[0][0
# __________________________________________________________________________________________________
# unet_down4_conv_3_activation (R (None, 20, 20, 512)  0           unet_down4_conv_3[0][0]
# __________________________________________________________________________________________________
# unet_down5_encode_maxpool (MaxP (None, 10, 10, 512)  0           unet_down4_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_down5_conv_0 (Conv2D)      (None, 10, 10, 1024) 4719616     unet_down5_encode_maxpool[0][0]
# __________________________________________________________________________________________________
# unet_down5_conv_0_activation (R (None, 10, 10, 1024) 0           unet_down5_conv_0[0][0]
# __________________________________________________________________________________________________
# unet_down5_conv_1 (Conv2D)      (None, 10, 10, 1024) 9438208     unet_down5_conv_0_activation[0][0
# __________________________________________________________________________________________________
# unet_down5_conv_1_activation (R (None, 10, 10, 1024) 0           unet_down5_conv_1[0][0]
# __________________________________________________________________________________________________
# unet_down5_conv_2 (Conv2D)      (None, 10, 10, 1024) 9438208     unet_down5_conv_1_activation[0][0
# __________________________________________________________________________________________________
# unet_down5_conv_2_activation (R (None, 10, 10, 1024) 0           unet_down5_conv_2[0][0]
# __________________________________________________________________________________________________
# unet_down5_conv_3 (Conv2D)      (None, 10, 10, 1024) 9438208     unet_down5_conv_2_activation[0][0
# __________________________________________________________________________________________________
# unet_down5_conv_3_activation (R (None, 10, 10, 1024) 0           unet_down5_conv_3[0][0]
# __________________________________________________________________________________________________
# unet_up0_decode_unpool (UpSampl (None, 20, 20, 1024) 0           unet_down5_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_up0_conv_before_concat_0 ( (None, 20, 20, 512)  4719104     unet_up0_decode_unpool[0][0]
# __________________________________________________________________________________________________
# unet_up0_conv_before_concat_0_a (None, 20, 20, 512)  0           unet_up0_conv_before_concat_0[0][
# __________________________________________________________________________________________________
# unet_up0_concat (Concatenate)   (None, 20, 20, 1024) 0           unet_up0_conv_before_concat_0_act
#                                                                  unet_down4_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_0 (C (None, 20, 20, 512)  4719104     unet_up0_concat[0][0]
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_0_ac (None, 20, 20, 512)  0           unet_up0_conv_after_concat_0[0][0
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_1 (C (None, 20, 20, 512)  2359808     unet_up0_conv_after_concat_0_acti
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_1_ac (None, 20, 20, 512)  0           unet_up0_conv_after_concat_1[0][0
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_2 (C (None, 20, 20, 512)  2359808     unet_up0_conv_after_concat_1_acti
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_2_ac (None, 20, 20, 512)  0           unet_up0_conv_after_concat_2[0][0
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_3 (C (None, 20, 20, 512)  2359808     unet_up0_conv_after_concat_2_acti
# __________________________________________________________________________________________________
# unet_up0_conv_after_concat_3_ac (None, 20, 20, 512)  0           unet_up0_conv_after_concat_3[0][0
# __________________________________________________________________________________________________
# unet_up1_decode_unpool (UpSampl (None, 40, 40, 512)  0           unet_up0_conv_after_concat_3_acti
# __________________________________________________________________________________________________
# unet_up1_conv_before_concat_0 ( (None, 40, 40, 256)  1179904     unet_up1_decode_unpool[0][0]
# __________________________________________________________________________________________________
# unet_up1_conv_before_concat_0_a (None, 40, 40, 256)  0           unet_up1_conv_before_concat_0[0][
# __________________________________________________________________________________________________
# unet_up1_concat (Concatenate)   (None, 40, 40, 512)  0           unet_up1_conv_before_concat_0_act
#                                                                  unet_down3_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_0 (C (None, 40, 40, 256)  1179904     unet_up1_concat[0][0]
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_0_ac (None, 40, 40, 256)  0           unet_up1_conv_after_concat_0[0][0
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_1 (C (None, 40, 40, 256)  590080      unet_up1_conv_after_concat_0_acti
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_1_ac (None, 40, 40, 256)  0           unet_up1_conv_after_concat_1[0][0
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_2 (C (None, 40, 40, 256)  590080      unet_up1_conv_after_concat_1_acti
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_2_ac (None, 40, 40, 256)  0           unet_up1_conv_after_concat_2[0][0
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_3 (C (None, 40, 40, 256)  590080      unet_up1_conv_after_concat_2_acti
# __________________________________________________________________________________________________
# unet_up1_conv_after_concat_3_ac (None, 40, 40, 256)  0           unet_up1_conv_after_concat_3[0][0
# __________________________________________________________________________________________________
# unet_up2_decode_unpool (UpSampl (None, 80, 80, 256)  0           unet_up1_conv_after_concat_3_acti
# __________________________________________________________________________________________________
# unet_up2_conv_before_concat_0 ( (None, 80, 80, 128)  295040      unet_up2_decode_unpool[0][0]
# __________________________________________________________________________________________________
# unet_up2_conv_before_concat_0_a (None, 80, 80, 128)  0           unet_up2_conv_before_concat_0[0][
# __________________________________________________________________________________________________
# unet_up2_concat (Concatenate)   (None, 80, 80, 256)  0           unet_up2_conv_before_concat_0_act
#                                                                  unet_down2_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_0 (C (None, 80, 80, 128)  295040      unet_up2_concat[0][0]
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_0_ac (None, 80, 80, 128)  0           unet_up2_conv_after_concat_0[0][0
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_1 (C (None, 80, 80, 128)  147584      unet_up2_conv_after_concat_0_acti
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_1_ac (None, 80, 80, 128)  0           unet_up2_conv_after_concat_1[0][0
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_2 (C (None, 80, 80, 128)  147584      unet_up2_conv_after_concat_1_acti
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_2_ac (None, 80, 80, 128)  0           unet_up2_conv_after_concat_2[0][0
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_3 (C (None, 80, 80, 128)  147584      unet_up2_conv_after_concat_2_acti
# __________________________________________________________________________________________________
# unet_up2_conv_after_concat_3_ac (None, 80, 80, 128)  0           unet_up2_conv_after_concat_3[0][0
# __________________________________________________________________________________________________
# unet_up3_decode_unpool (UpSampl (None, 160, 160, 128 0           unet_up2_conv_after_concat_3_acti
# __________________________________________________________________________________________________
# unet_up3_conv_before_concat_0 ( (None, 160, 160, 64) 73792       unet_up3_decode_unpool[0][0]
# __________________________________________________________________________________________________
# unet_up3_conv_before_concat_0_a (None, 160, 160, 64) 0           unet_up3_conv_before_concat_0[0][
# __________________________________________________________________________________________________
# unet_up3_concat (Concatenate)   (None, 160, 160, 128 0           unet_up3_conv_before_concat_0_act
#                                                                  unet_down1_conv_3_activation[0][0
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_0 (C (None, 160, 160, 64) 73792       unet_up3_concat[0][0]
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_0_ac (None, 160, 160, 64) 0           unet_up3_conv_after_concat_0[0][0
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_1 (C (None, 160, 160, 64) 36928       unet_up3_conv_after_concat_0_acti
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_1_ac (None, 160, 160, 64) 0           unet_up3_conv_after_concat_1[0][0
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_2 (C (None, 160, 160, 64) 36928       unet_up3_conv_after_concat_1_acti
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_2_ac (None, 160, 160, 64) 0           unet_up3_conv_after_concat_2[0][0
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_3 (C (None, 160, 160, 64) 36928       unet_up3_conv_after_concat_2_acti
# __________________________________________________________________________________________________
# unet_up3_conv_after_concat_3_ac (None, 160, 160, 64) 0           unet_up3_conv_after_concat_3[0][0
# __________________________________________________________________________________________________
# unet_up4_decode_unpool (UpSampl (None, 320, 320, 64) 0           unet_up3_conv_after_concat_3_acti
# __________________________________________________________________________________________________
# unet_up4_conv_before_concat_0 ( (None, 320, 320, 32) 18464       unet_up4_decode_unpool[0][0]
# __________________________________________________________________________________________________
# unet_up4_conv_before_concat_0_a (None, 320, 320, 32) 0           unet_up4_conv_before_concat_0[0][
# __________________________________________________________________________________________________
# unet_up4_concat (Concatenate)   (None, 320, 320, 64) 0           unet_up4_conv_before_concat_0_act
#                                                                  unet_down0_3_activation[0][0]
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_0 (C (None, 320, 320, 32) 18464       unet_up4_concat[0][0]
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_0_ac (None, 320, 320, 32) 0           unet_up4_conv_after_concat_0[0][0
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_1 (C (None, 320, 320, 32) 9248        unet_up4_conv_after_concat_0_acti
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_1_ac (None, 320, 320, 32) 0           unet_up4_conv_after_concat_1[0][0
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_2 (C (None, 320, 320, 32) 9248        unet_up4_conv_after_concat_1_acti
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_2_ac (None, 320, 320, 32) 0           unet_up4_conv_after_concat_2[0][0
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_3 (C (None, 320, 320, 32) 9248        unet_up4_conv_after_concat_2_acti
# __________________________________________________________________________________________________
# unet_up4_conv_after_concat_3_ac (None, 320, 320, 32) 0           unet_up4_conv_after_concat_3[0][0
# __________________________________________________________________________________________________
# unet_output (Conv2D)            (None, 320, 320, 1)  33          unet_up4_conv_after_concat_3_acti
# __________________________________________________________________________________________________
# unet_output_activation (Activat (None, 320, 320, 1)  0           unet_output[0][0]
# ==================================================================================================
# Total params: 66,036,769
# Trainable params: 66,036,769
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model = models.u2net_2d((320, 320, 1), filter_num_down=[32, 64, 128, 256, 512], n_labels=1, output_activation='Sigmoid', deep_supervision=True)
model.summary()
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of RSU output channels within downsampling blocks: filter_num_down = [32, 64, 128, 256, 512]
# 	Number of RSU intermediate channels within downsampling blocks: filter_mid_num_down = [8, 16, 32, 64, 128]
# 	Number of RSU output channels within upsampling blocks: filter_num_up = [32, 64, 128, 256, 512]
# 	Number of RSU intermediate channels within upsampling blocks: filter_mid_num_up = [8, 16, 32, 64, 128]
# 	Number of RSU-4F output channels within downsampling and bottom blocks: filter_4f_num = [512, 512]
# 	Number of RSU-4F intermediate channels within downsampling and bottom blocks: filter_4f_num = [256, 256]
# ----------
# Explicitly specifying keywords listed above if their "auto" settings do not satisfy your needs
# ----------
# The depth of u2net_2d = len(filter_num_down) + len(filter_4f_num) = 7
# ----------
# deep_supervision = True
# names of output tensors are listed as follows ("sup0" is the shallowest supervision layer;
# "final" is the final output layer):
#
# 	u2net_output_sup0_activation
# 	u2net_output_sup1_activation
# 	u2net_output_sup2_activation
# 	u2net_output_sup3_activation
# 	u2net_output_sup4_activation
# 	u2net_output_sup5_activation
# 	u2net_output_sup6_activation
# 	u2net_output_final_activation
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_50 (InputLayer)           [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# u2net_in_in_0 (Conv2D)          (None, 320, 320, 32) 320         input_50[0][0]
# __________________________________________________________________________________________________
# u2net_in_in_0_activation (ReLU) (None, 320, 320, 32) 0           u2net_in_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_0_0 (Conv2D)      (None, 320, 320, 8)  2312        u2net_in_in_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_0_0_activation (R (None, 320, 320, 8)  0           u2net_in_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_0_maxpool (MaxP (None, 160, 160, 8)  0           u2net_in_down_0_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_1_0 (Conv2D)      (None, 160, 160, 8)  584         u2net_in_encode_0_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_1_0_activation (R (None, 160, 160, 8)  0           u2net_in_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_1_maxpool (MaxP (None, 80, 80, 8)    0           u2net_in_down_1_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_2_0 (Conv2D)      (None, 80, 80, 8)    584         u2net_in_encode_1_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_2_0_activation (R (None, 80, 80, 8)    0           u2net_in_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_2_maxpool (MaxP (None, 40, 40, 8)    0           u2net_in_down_2_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_3_0 (Conv2D)      (None, 40, 40, 8)    584         u2net_in_encode_2_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_3_0_activation (R (None, 40, 40, 8)    0           u2net_in_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_3_maxpool (MaxP (None, 20, 20, 8)    0           u2net_in_down_3_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_4_0 (Conv2D)      (None, 20, 20, 8)    584         u2net_in_encode_3_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_4_0_activation (R (None, 20, 20, 8)    0           u2net_in_down_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_4_maxpool (MaxP (None, 10, 10, 8)    0           u2net_in_down_4_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_5_0 (Conv2D)      (None, 10, 10, 8)    584         u2net_in_encode_4_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_5_0_activation (R (None, 10, 10, 8)    0           u2net_in_down_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_encode_5_maxpool (MaxP (None, 5, 5, 8)      0           u2net_in_down_5_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_down_6_0 (Conv2D)      (None, 5, 5, 8)      584         u2net_in_encode_5_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_in_down_6_0_activation (R (None, 5, 5, 8)      0           u2net_in_down_6_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_0_0 (Conv2D)        (None, 5, 5, 8)      584         u2net_in_down_6_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_0_0_activation (ReL (None, 5, 5, 8)      0           u2net_in_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_0 (Concatenate) (None, 5, 5, 16)     0           u2net_in_up_0_0_activation[0][0]
#                                                                  u2net_in_down_6_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_1_0 (Conv2D)        (None, 5, 5, 8)      1160        u2net_in_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_1_0_activation (ReL (None, 5, 5, 8)      0           u2net_in_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_0_unpool (UpSam (None, 10, 10, 8)    0           u2net_in_up_1_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_1 (Concatenate) (None, 10, 10, 16)   0           u2net_in_decode_0_unpool[0][0]
#                                                                  u2net_in_down_5_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_2_0 (Conv2D)        (None, 10, 10, 8)    1160        u2net_in_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_2_0_activation (ReL (None, 10, 10, 8)    0           u2net_in_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_1_unpool (UpSam (None, 20, 20, 8)    0           u2net_in_up_2_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_2 (Concatenate) (None, 20, 20, 16)   0           u2net_in_decode_1_unpool[0][0]
#                                                                  u2net_in_down_4_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_3_0 (Conv2D)        (None, 20, 20, 8)    1160        u2net_in_concat_2[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_3_0_activation (ReL (None, 20, 20, 8)    0           u2net_in_up_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_2_unpool (UpSam (None, 40, 40, 8)    0           u2net_in_up_3_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_3 (Concatenate) (None, 40, 40, 16)   0           u2net_in_decode_2_unpool[0][0]
#                                                                  u2net_in_down_3_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_4_0 (Conv2D)        (None, 40, 40, 8)    1160        u2net_in_concat_3[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_4_0_activation (ReL (None, 40, 40, 8)    0           u2net_in_up_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_3_unpool (UpSam (None, 80, 80, 8)    0           u2net_in_up_4_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_4 (Concatenate) (None, 80, 80, 16)   0           u2net_in_decode_3_unpool[0][0]
#                                                                  u2net_in_down_2_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_5_0 (Conv2D)        (None, 80, 80, 8)    1160        u2net_in_concat_4[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_5_0_activation (ReL (None, 80, 80, 8)    0           u2net_in_up_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_4_unpool (UpSam (None, 160, 160, 8)  0           u2net_in_up_5_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_5 (Concatenate) (None, 160, 160, 16) 0           u2net_in_decode_4_unpool[0][0]
#                                                                  u2net_in_down_1_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_up_6_0 (Conv2D)        (None, 160, 160, 8)  1160        u2net_in_concat_5[0][0]
# __________________________________________________________________________________________________
# u2net_in_up_6_0_activation (ReL (None, 160, 160, 8)  0           u2net_in_up_6_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_decode_5_unpool (UpSam (None, 320, 320, 8)  0           u2net_in_up_6_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_in_concat_out (Concatenat (None, 320, 320, 16) 0           u2net_in_decode_5_unpool[0][0]
#                                                                  u2net_in_down_0_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_in_out_0 (Conv2D)         (None, 320, 320, 32) 4640        u2net_in_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_in_out_0_activation (ReLU (None, 320, 320, 32) 0           u2net_in_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_in_out_add (Add)          (None, 320, 320, 32) 0           u2net_in_out_0_activation[0][0]
#                                                                  u2net_in_in_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_encode_0_maxpool (MaxPool (None, 160, 160, 32) 0           u2net_in_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_in_0 (Conv2D)      (None, 160, 160, 64) 18496       u2net_encode_0_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_in_0_activation (R (None, 160, 160, 64) 0           u2net_down_0_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_down_0_0 (Conv2D)  (None, 160, 160, 16) 9232        u2net_down_0_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_down_0_down_0_0_activatio (None, 160, 160, 16) 0           u2net_down_0_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_encode_0_maxpool ( (None, 80, 80, 16)   0           u2net_down_0_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_down_1_0 (Conv2D)  (None, 80, 80, 16)   2320        u2net_down_0_encode_0_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_0_down_1_0_activatio (None, 80, 80, 16)   0           u2net_down_0_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_encode_1_maxpool ( (None, 40, 40, 16)   0           u2net_down_0_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_down_2_0 (Conv2D)  (None, 40, 40, 16)   2320        u2net_down_0_encode_1_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_0_down_2_0_activatio (None, 40, 40, 16)   0           u2net_down_0_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_encode_2_maxpool ( (None, 20, 20, 16)   0           u2net_down_0_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_down_3_0 (Conv2D)  (None, 20, 20, 16)   2320        u2net_down_0_encode_2_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_0_down_3_0_activatio (None, 20, 20, 16)   0           u2net_down_0_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_encode_3_maxpool ( (None, 10, 10, 16)   0           u2net_down_0_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_down_4_0 (Conv2D)  (None, 10, 10, 16)   2320        u2net_down_0_encode_3_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_0_down_4_0_activatio (None, 10, 10, 16)   0           u2net_down_0_down_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_encode_4_maxpool ( (None, 5, 5, 16)     0           u2net_down_0_down_4_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_down_5_0 (Conv2D)  (None, 5, 5, 16)     2320        u2net_down_0_encode_4_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_0_down_5_0_activatio (None, 5, 5, 16)     0           u2net_down_0_down_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_0_0 (Conv2D)    (None, 5, 5, 16)     2320        u2net_down_0_down_5_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_0_0_activation  (None, 5, 5, 16)     0           u2net_down_0_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_0 (Concaten (None, 5, 5, 32)     0           u2net_down_0_up_0_0_activation[0]
#                                                                  u2net_down_0_down_5_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_1_0 (Conv2D)    (None, 5, 5, 16)     4624        u2net_down_0_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_1_0_activation  (None, 5, 5, 16)     0           u2net_down_0_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_decode_0_unpool (U (None, 10, 10, 16)   0           u2net_down_0_up_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_1 (Concaten (None, 10, 10, 32)   0           u2net_down_0_decode_0_unpool[0][0
#                                                                  u2net_down_0_down_4_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_2_0 (Conv2D)    (None, 10, 10, 16)   4624        u2net_down_0_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_2_0_activation  (None, 10, 10, 16)   0           u2net_down_0_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_decode_1_unpool (U (None, 20, 20, 16)   0           u2net_down_0_up_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_2 (Concaten (None, 20, 20, 32)   0           u2net_down_0_decode_1_unpool[0][0
#                                                                  u2net_down_0_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_3_0 (Conv2D)    (None, 20, 20, 16)   4624        u2net_down_0_concat_2[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_3_0_activation  (None, 20, 20, 16)   0           u2net_down_0_up_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_decode_2_unpool (U (None, 40, 40, 16)   0           u2net_down_0_up_3_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_3 (Concaten (None, 40, 40, 32)   0           u2net_down_0_decode_2_unpool[0][0
#                                                                  u2net_down_0_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_4_0 (Conv2D)    (None, 40, 40, 16)   4624        u2net_down_0_concat_3[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_4_0_activation  (None, 40, 40, 16)   0           u2net_down_0_up_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_decode_3_unpool (U (None, 80, 80, 16)   0           u2net_down_0_up_4_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_4 (Concaten (None, 80, 80, 32)   0           u2net_down_0_decode_3_unpool[0][0
#                                                                  u2net_down_0_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_up_5_0 (Conv2D)    (None, 80, 80, 16)   4624        u2net_down_0_concat_4[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_up_5_0_activation  (None, 80, 80, 16)   0           u2net_down_0_up_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_decode_4_unpool (U (None, 160, 160, 16) 0           u2net_down_0_up_5_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_0_concat_out (Concat (None, 160, 160, 32) 0           u2net_down_0_decode_4_unpool[0][0
#                                                                  u2net_down_0_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_0_out_0 (Conv2D)     (None, 160, 160, 64) 18496       u2net_down_0_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_out_0_activation ( (None, 160, 160, 64) 0           u2net_down_0_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_0_out_add (Add)      (None, 160, 160, 64) 0           u2net_down_0_out_0_activation[0][
#                                                                  u2net_down_0_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_encode_1_maxpool (MaxPool (None, 80, 80, 64)   0           u2net_down_0_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_in_0 (Conv2D)      (None, 80, 80, 128)  73856       u2net_encode_1_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_in_0_activation (R (None, 80, 80, 128)  0           u2net_down_1_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_down_0_0 (Conv2D)  (None, 80, 80, 32)   36896       u2net_down_1_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_down_1_down_0_0_activatio (None, 80, 80, 32)   0           u2net_down_1_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_encode_0_maxpool ( (None, 40, 40, 32)   0           u2net_down_1_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_down_1_0 (Conv2D)  (None, 40, 40, 32)   9248        u2net_down_1_encode_0_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_1_down_1_0_activatio (None, 40, 40, 32)   0           u2net_down_1_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_encode_1_maxpool ( (None, 20, 20, 32)   0           u2net_down_1_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_down_2_0 (Conv2D)  (None, 20, 20, 32)   9248        u2net_down_1_encode_1_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_1_down_2_0_activatio (None, 20, 20, 32)   0           u2net_down_1_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_encode_2_maxpool ( (None, 10, 10, 32)   0           u2net_down_1_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_down_3_0 (Conv2D)  (None, 10, 10, 32)   9248        u2net_down_1_encode_2_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_1_down_3_0_activatio (None, 10, 10, 32)   0           u2net_down_1_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_encode_3_maxpool ( (None, 5, 5, 32)     0           u2net_down_1_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_down_4_0 (Conv2D)  (None, 5, 5, 32)     9248        u2net_down_1_encode_3_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_1_down_4_0_activatio (None, 5, 5, 32)     0           u2net_down_1_down_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_up_0_0 (Conv2D)    (None, 5, 5, 32)     9248        u2net_down_1_down_4_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_up_0_0_activation  (None, 5, 5, 32)     0           u2net_down_1_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_concat_0 (Concaten (None, 5, 5, 64)     0           u2net_down_1_up_0_0_activation[0]
#                                                                  u2net_down_1_down_4_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_up_1_0 (Conv2D)    (None, 5, 5, 32)     18464       u2net_down_1_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_up_1_0_activation  (None, 5, 5, 32)     0           u2net_down_1_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_decode_0_unpool (U (None, 10, 10, 32)   0           u2net_down_1_up_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_1_concat_1 (Concaten (None, 10, 10, 64)   0           u2net_down_1_decode_0_unpool[0][0
#                                                                  u2net_down_1_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_up_2_0 (Conv2D)    (None, 10, 10, 32)   18464       u2net_down_1_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_up_2_0_activation  (None, 10, 10, 32)   0           u2net_down_1_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_decode_1_unpool (U (None, 20, 20, 32)   0           u2net_down_1_up_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_1_concat_2 (Concaten (None, 20, 20, 64)   0           u2net_down_1_decode_1_unpool[0][0
#                                                                  u2net_down_1_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_up_3_0 (Conv2D)    (None, 20, 20, 32)   18464       u2net_down_1_concat_2[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_up_3_0_activation  (None, 20, 20, 32)   0           u2net_down_1_up_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_decode_2_unpool (U (None, 40, 40, 32)   0           u2net_down_1_up_3_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_1_concat_3 (Concaten (None, 40, 40, 64)   0           u2net_down_1_decode_2_unpool[0][0
#                                                                  u2net_down_1_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_up_4_0 (Conv2D)    (None, 40, 40, 32)   18464       u2net_down_1_concat_3[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_up_4_0_activation  (None, 40, 40, 32)   0           u2net_down_1_up_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_decode_3_unpool (U (None, 80, 80, 32)   0           u2net_down_1_up_4_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_1_concat_out (Concat (None, 80, 80, 64)   0           u2net_down_1_decode_3_unpool[0][0
#                                                                  u2net_down_1_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_1_out_0 (Conv2D)     (None, 80, 80, 128)  73856       u2net_down_1_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_out_0_activation ( (None, 80, 80, 128)  0           u2net_down_1_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_1_out_add (Add)      (None, 80, 80, 128)  0           u2net_down_1_out_0_activation[0][
#                                                                  u2net_down_1_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_encode_2_maxpool (MaxPool (None, 40, 40, 128)  0           u2net_down_1_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_in_0 (Conv2D)      (None, 40, 40, 256)  295168      u2net_encode_2_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_in_0_activation (R (None, 40, 40, 256)  0           u2net_down_2_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_down_0_0 (Conv2D)  (None, 40, 40, 64)   147520      u2net_down_2_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_down_2_down_0_0_activatio (None, 40, 40, 64)   0           u2net_down_2_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_encode_0_maxpool ( (None, 20, 20, 64)   0           u2net_down_2_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_down_1_0 (Conv2D)  (None, 20, 20, 64)   36928       u2net_down_2_encode_0_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_2_down_1_0_activatio (None, 20, 20, 64)   0           u2net_down_2_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_encode_1_maxpool ( (None, 10, 10, 64)   0           u2net_down_2_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_down_2_0 (Conv2D)  (None, 10, 10, 64)   36928       u2net_down_2_encode_1_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_2_down_2_0_activatio (None, 10, 10, 64)   0           u2net_down_2_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_encode_2_maxpool ( (None, 5, 5, 64)     0           u2net_down_2_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_down_3_0 (Conv2D)  (None, 5, 5, 64)     36928       u2net_down_2_encode_2_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_2_down_3_0_activatio (None, 5, 5, 64)     0           u2net_down_2_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_up_0_0 (Conv2D)    (None, 5, 5, 64)     36928       u2net_down_2_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_up_0_0_activation  (None, 5, 5, 64)     0           u2net_down_2_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_concat_0 (Concaten (None, 5, 5, 128)    0           u2net_down_2_up_0_0_activation[0]
#                                                                  u2net_down_2_down_3_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_up_1_0 (Conv2D)    (None, 5, 5, 64)     73792       u2net_down_2_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_up_1_0_activation  (None, 5, 5, 64)     0           u2net_down_2_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_decode_0_unpool (U (None, 10, 10, 64)   0           u2net_down_2_up_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_2_concat_1 (Concaten (None, 10, 10, 128)  0           u2net_down_2_decode_0_unpool[0][0
#                                                                  u2net_down_2_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_up_2_0 (Conv2D)    (None, 10, 10, 64)   73792       u2net_down_2_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_up_2_0_activation  (None, 10, 10, 64)   0           u2net_down_2_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_decode_1_unpool (U (None, 20, 20, 64)   0           u2net_down_2_up_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_2_concat_2 (Concaten (None, 20, 20, 128)  0           u2net_down_2_decode_1_unpool[0][0
#                                                                  u2net_down_2_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_up_3_0 (Conv2D)    (None, 20, 20, 64)   73792       u2net_down_2_concat_2[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_up_3_0_activation  (None, 20, 20, 64)   0           u2net_down_2_up_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_decode_2_unpool (U (None, 40, 40, 64)   0           u2net_down_2_up_3_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_2_concat_out (Concat (None, 40, 40, 128)  0           u2net_down_2_decode_2_unpool[0][0
#                                                                  u2net_down_2_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_2_out_0 (Conv2D)     (None, 40, 40, 256)  295168      u2net_down_2_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_out_0_activation ( (None, 40, 40, 256)  0           u2net_down_2_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_2_out_add (Add)      (None, 40, 40, 256)  0           u2net_down_2_out_0_activation[0][
#                                                                  u2net_down_2_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_encode_3_maxpool (MaxPool (None, 20, 20, 256)  0           u2net_down_2_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_in_0 (Conv2D)      (None, 20, 20, 512)  1180160     u2net_encode_3_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_in_0_activation (R (None, 20, 20, 512)  0           u2net_down_3_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_down_0_0 (Conv2D)  (None, 20, 20, 128)  589952      u2net_down_3_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_down_3_down_0_0_activatio (None, 20, 20, 128)  0           u2net_down_3_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_encode_0_maxpool ( (None, 10, 10, 128)  0           u2net_down_3_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_down_1_0 (Conv2D)  (None, 10, 10, 128)  147584      u2net_down_3_encode_0_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_3_down_1_0_activatio (None, 10, 10, 128)  0           u2net_down_3_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_encode_1_maxpool ( (None, 5, 5, 128)    0           u2net_down_3_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_down_2_0 (Conv2D)  (None, 5, 5, 128)    147584      u2net_down_3_encode_1_maxpool[0][
# __________________________________________________________________________________________________
# u2net_down_3_down_2_0_activatio (None, 5, 5, 128)    0           u2net_down_3_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_up_0_0 (Conv2D)    (None, 5, 5, 128)    147584      u2net_down_3_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_up_0_0_activation  (None, 5, 5, 128)    0           u2net_down_3_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_concat_0 (Concaten (None, 5, 5, 256)    0           u2net_down_3_up_0_0_activation[0]
#                                                                  u2net_down_3_down_2_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_up_1_0 (Conv2D)    (None, 5, 5, 128)    295040      u2net_down_3_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_up_1_0_activation  (None, 5, 5, 128)    0           u2net_down_3_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_decode_0_unpool (U (None, 10, 10, 128)  0           u2net_down_3_up_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_3_concat_1 (Concaten (None, 10, 10, 256)  0           u2net_down_3_decode_0_unpool[0][0
#                                                                  u2net_down_3_down_1_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_up_2_0 (Conv2D)    (None, 10, 10, 128)  295040      u2net_down_3_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_up_2_0_activation  (None, 10, 10, 128)  0           u2net_down_3_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_decode_1_unpool (U (None, 20, 20, 128)  0           u2net_down_3_up_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_down_3_concat_out (Concat (None, 20, 20, 256)  0           u2net_down_3_decode_1_unpool[0][0
#                                                                  u2net_down_3_down_0_0_activation[
# __________________________________________________________________________________________________
# u2net_down_3_out_0 (Conv2D)     (None, 20, 20, 512)  1180160     u2net_down_3_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_out_0_activation ( (None, 20, 20, 512)  0           u2net_down_3_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_3_out_add (Add)      (None, 20, 20, 512)  0           u2net_down_3_out_0_activation[0][
#                                                                  u2net_down_3_in_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_encode_4f_0_maxpool (MaxP (None, 10, 10, 512)  0           u2net_down_3_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_in_0 (Conv2D)   (None, 10, 10, 512)  2359808     u2net_encode_4f_0_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_in_0_activation (None, 10, 10, 512)  0           u2net_down_4f_0_in_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_0_0 (Conv2 (None, 10, 10, 256)  1179904     u2net_down_4f_0_in_0_activation[0
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_0_0_activa (None, 10, 10, 256)  0           u2net_down_4f_0_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_1_0 (Conv2 (None, 10, 10, 256)  590080      u2net_down_4f_0_down_0_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_1_0_activa (None, 10, 10, 256)  0           u2net_down_4f_0_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_2_0 (Conv2 (None, 10, 10, 256)  590080      u2net_down_4f_0_down_1_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_2_0_activa (None, 10, 10, 256)  0           u2net_down_4f_0_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_3_0 (Conv2 (None, 10, 10, 256)  590080      u2net_down_4f_0_down_2_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_down_3_0_activa (None, 10, 10, 256)  0           u2net_down_4f_0_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_concat_0 (Conca (None, 10, 10, 512)  0           u2net_down_4f_0_down_3_0_activati
#                                                                  u2net_down_4f_0_down_2_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_up_0_0 (Conv2D) (None, 10, 10, 256)  1179904     u2net_down_4f_0_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_up_0_0_activati (None, 10, 10, 256)  0           u2net_down_4f_0_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_concat_1 (Conca (None, 10, 10, 512)  0           u2net_down_4f_0_up_0_0_activation
#                                                                  u2net_down_4f_0_down_1_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_up_1_0 (Conv2D) (None, 10, 10, 256)  1179904     u2net_down_4f_0_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_up_1_0_activati (None, 10, 10, 256)  0           u2net_down_4f_0_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_concat_out (Con (None, 10, 10, 512)  0           u2net_down_4f_0_up_1_0_activation
#                                                                  u2net_down_4f_0_down_0_0_activati
# __________________________________________________________________________________________________
# u2net_down_4f_0_out_0 (Conv2D)  (None, 10, 10, 512)  2359808     u2net_down_4f_0_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_out_0_activatio (None, 10, 10, 512)  0           u2net_down_4f_0_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_down_4f_0_out_add (Add)   (None, 10, 10, 512)  0           u2net_down_4f_0_out_0_activation[
#                                                                  u2net_down_4f_0_in_0_activation[0
# __________________________________________________________________________________________________
# u2net_encode_4f_1_maxpool (MaxP (None, 5, 5, 512)    0           u2net_down_4f_0_out_add[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# u2net_up_4_down_0_0_activation  (None, 320, 320, 8)  0           u2net_up_4_down_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_0_maxpool (Ma (None, 160, 160, 8)  0           u2net_up_4_down_0_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_1_0 (Conv2D)    (None, 160, 160, 8)  584         u2net_up_4_encode_0_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_1_0_activation  (None, 160, 160, 8)  0           u2net_up_4_down_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_1_maxpool (Ma (None, 80, 80, 8)    0           u2net_up_4_down_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_2_0 (Conv2D)    (None, 80, 80, 8)    584         u2net_up_4_encode_1_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_2_0_activation  (None, 80, 80, 8)    0           u2net_up_4_down_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_2_maxpool (Ma (None, 40, 40, 8)    0           u2net_up_4_down_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_3_0 (Conv2D)    (None, 40, 40, 8)    584         u2net_up_4_encode_2_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_3_0_activation  (None, 40, 40, 8)    0           u2net_up_4_down_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_3_maxpool (Ma (None, 20, 20, 8)    0           u2net_up_4_down_3_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_4_0 (Conv2D)    (None, 20, 20, 8)    584         u2net_up_4_encode_3_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_4_0_activation  (None, 20, 20, 8)    0           u2net_up_4_down_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_4_maxpool (Ma (None, 10, 10, 8)    0           u2net_up_4_down_4_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_5_0 (Conv2D)    (None, 10, 10, 8)    584         u2net_up_4_encode_4_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_5_0_activation  (None, 10, 10, 8)    0           u2net_up_4_down_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_encode_5_maxpool (Ma (None, 5, 5, 8)      0           u2net_up_4_down_5_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_down_6_0 (Conv2D)    (None, 5, 5, 8)      584         u2net_up_4_encode_5_maxpool[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_down_6_0_activation  (None, 5, 5, 8)      0           u2net_up_4_down_6_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_0_0 (Conv2D)      (None, 5, 5, 8)      584         u2net_up_4_down_6_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_0_0_activation (R (None, 5, 5, 8)      0           u2net_up_4_up_0_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_concat_0 (Concatenat (None, 5, 5, 16)     0           u2net_up_4_up_0_0_activation[0][0
#                                                                  u2net_up_4_down_6_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_1_0 (Conv2D)      (None, 5, 5, 8)      1160        u2net_up_4_concat_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_1_0_activation (R (None, 5, 5, 8)      0           u2net_up_4_up_1_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_0_unpool (UpS (None, 10, 10, 8)    0           u2net_up_4_up_1_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_1 (Concatenat (None, 10, 10, 16)   0           u2net_up_4_decode_0_unpool[0][0]
#                                                                  u2net_up_4_down_5_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_2_0 (Conv2D)      (None, 10, 10, 8)    1160        u2net_up_4_concat_1[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_2_0_activation (R (None, 10, 10, 8)    0           u2net_up_4_up_2_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_1_unpool (UpS (None, 20, 20, 8)    0           u2net_up_4_up_2_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_2 (Concatenat (None, 20, 20, 16)   0           u2net_up_4_decode_1_unpool[0][0]
#                                                                  u2net_up_4_down_4_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_3_0 (Conv2D)      (None, 20, 20, 8)    1160        u2net_up_4_concat_2[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_3_0_activation (R (None, 20, 20, 8)    0           u2net_up_4_up_3_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_2_unpool (UpS (None, 40, 40, 8)    0           u2net_up_4_up_3_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_3 (Concatenat (None, 40, 40, 16)   0           u2net_up_4_decode_2_unpool[0][0]
#                                                                  u2net_up_4_down_3_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_4_0 (Conv2D)      (None, 40, 40, 8)    1160        u2net_up_4_concat_3[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_4_0_activation (R (None, 40, 40, 8)    0           u2net_up_4_up_4_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_3_unpool (UpS (None, 80, 80, 8)    0           u2net_up_4_up_4_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_4 (Concatenat (None, 80, 80, 16)   0           u2net_up_4_decode_3_unpool[0][0]
#                                                                  u2net_up_4_down_2_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_5_0 (Conv2D)      (None, 80, 80, 8)    1160        u2net_up_4_concat_4[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_5_0_activation (R (None, 80, 80, 8)    0           u2net_up_4_up_5_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_4_unpool (UpS (None, 160, 160, 8)  0           u2net_up_4_up_5_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_5 (Concatenat (None, 160, 160, 16) 0           u2net_up_4_decode_4_unpool[0][0]
#                                                                  u2net_up_4_down_1_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_up_6_0 (Conv2D)      (None, 160, 160, 8)  1160        u2net_up_4_concat_5[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_up_6_0_activation (R (None, 160, 160, 8)  0           u2net_up_4_up_6_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_decode_5_unpool (UpS (None, 320, 320, 8)  0           u2net_up_4_up_6_0_activation[0][0
# __________________________________________________________________________________________________
# u2net_up_4_concat_out (Concaten (None, 320, 320, 16) 0           u2net_up_4_decode_5_unpool[0][0]
#                                                                  u2net_up_4_down_0_0_activation[0]
# __________________________________________________________________________________________________
# u2net_up_4_out_0 (Conv2D)       (None, 320, 320, 32) 4640        u2net_up_4_concat_out[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_out_0_activation (Re (None, 320, 320, 32) 0           u2net_up_4_out_0[0][0]
# __________________________________________________________________________________________________
# u2net_up_4_out_add (Add)        (None, 320, 320, 32) 0           u2net_up_4_out_0_activation[0][0]
#                                                                  u2net_up_4_in_0_activation[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_1 (Conv2D)    (None, 160, 160, 1)  577         u2net_up_3_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_2 (Conv2D)    (None, 80, 80, 1)    1153        u2net_up_2_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_3 (Conv2D)    (None, 40, 40, 1)    2305        u2net_up_1_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_4 (Conv2D)    (None, 20, 20, 1)    4609        u2net_up_0_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_5 (Conv2D)    (None, 10, 10, 1)    4609        u2net_up_4f_0_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_conv_6 (Conv2D)    (None, 5, 5, 1)      4609        u2net_down_4f_1_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup0 (Conv2D)      (None, 320, 320, 1)  289         u2net_up_4_out_add[0][0]
# __________________________________________________________________________________________________
# u2net_sup1_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_1[0][0]
# __________________________________________________________________________________________________
# u2net_sup2_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_2[0][0]
# __________________________________________________________________________________________________
# u2net_sup3_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_3[0][0]
# __________________________________________________________________________________________________
# u2net_sup4_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_4[0][0]
# __________________________________________________________________________________________________
# u2net_sup5_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_5[0][0]
# __________________________________________________________________________________________________
# u2net_sup6_unpool (UpSampling2D (None, 320, 320, 1)  0           u2net_output_conv_6[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup0_activation (A (None, 320, 320, 1)  0           u2net_output_sup0[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup1_activation (A (None, 320, 320, 1)  0           u2net_sup1_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup2_activation (A (None, 320, 320, 1)  0           u2net_sup2_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup3_activation (A (None, 320, 320, 1)  0           u2net_sup3_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup4_activation (A (None, 320, 320, 1)  0           u2net_sup4_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup5_activation (A (None, 320, 320, 1)  0           u2net_sup5_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_sup6_activation (A (None, 320, 320, 1)  0           u2net_sup6_unpool[0][0]
# __________________________________________________________________________________________________
# u2net_output_concat (Concatenat (None, 320, 320, 7)  0           u2net_output_sup0_activation[0][0
#                                                                  u2net_output_sup1_activation[0][0
#                                                                  u2net_output_sup2_activation[0][0
#                                                                  u2net_output_sup3_activation[0][0
#                                                                  u2net_output_sup4_activation[0][0
#                                                                  u2net_output_sup5_activation[0][0
#                                                                  u2net_output_sup6_activation[0][0
# __________________________________________________________________________________________________
# u2net_output_final (Conv2D)     (None, 320, 320, 1)  8           u2net_output_concat[0][0]
# __________________________________________________________________________________________________
# u2net_output_final_activation ( (None, 320, 320, 1)  0           u2net_output_final[0][0]
# ==================================================================================================
# Total params: 48,960,495
# Trainable params: 48,960,495
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model = get_model('unet_3plus_2d', image_input_shape, [32, 64, 128, 256, 512, 1024])
model = models.unet_3plus_2d((320, 320, 1), n_labels=1, filter_num_down=[32, 64, 128, 256, 512, 1024], stack_num_down=4, stack_num_up=4, output_activation='Sigmoid')
model.summary()
# Out:
# Automated hyper-parameter determination is applied with the following details:
# ----------
# 	Number of convolution filters after each full-scale skip connection: filter_num_skip = [32, 32, 32, 32, 32]
# 	Number of channels of full-scale aggregated feature maps: filter_num_aggregate = 192
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# unet3plus_down0_0 (Conv2D)      (None, 320, 320, 32) 320         input_5[0][0]
# __________________________________________________________________________________________________
# unet3plus_down0_0_activation (R (None, 320, 320, 32) 0           unet3plus_down0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down0_1 (Conv2D)      (None, 320, 320, 32) 9248        unet3plus_down0_0_activation[0][0
# __________________________________________________________________________________________________
# unet3plus_down0_1_activation (R (None, 320, 320, 32) 0           unet3plus_down0_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down0_2 (Conv2D)      (None, 320, 320, 32) 9248        unet3plus_down0_1_activation[0][0
# __________________________________________________________________________________________________
# unet3plus_down0_2_activation (R (None, 320, 320, 32) 0           unet3plus_down0_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down0_3 (Conv2D)      (None, 320, 320, 32) 9248        unet3plus_down0_2_activation[0][0
# __________________________________________________________________________________________________
# unet3plus_down0_3_activation (R (None, 320, 320, 32) 0           unet3plus_down0_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_down1_encode_maxpool  (None, 160, 160, 32) 0           unet3plus_down0_3_activation[0][0
# __________________________________________________________________________________________________
# unet3plus_down1_conv_0 (Conv2D) (None, 160, 160, 64) 18496       unet3plus_down1_encode_maxpool[0]
# __________________________________________________________________________________________________
# unet3plus_down1_conv_0_activati (None, 160, 160, 64) 0           unet3plus_down1_conv_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down1_conv_1 (Conv2D) (None, 160, 160, 64) 36928       unet3plus_down1_conv_0_activation
# __________________________________________________________________________________________________
# unet3plus_down1_conv_1_activati (None, 160, 160, 64) 0           unet3plus_down1_conv_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down1_conv_2 (Conv2D) (None, 160, 160, 64) 36928       unet3plus_down1_conv_1_activation
# __________________________________________________________________________________________________
# unet3plus_down1_conv_2_activati (None, 160, 160, 64) 0           unet3plus_down1_conv_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down1_conv_3 (Conv2D) (None, 160, 160, 64) 36928       unet3plus_down1_conv_2_activation
# __________________________________________________________________________________________________
# unet3plus_down1_conv_3_activati (None, 160, 160, 64) 0           unet3plus_down1_conv_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_down2_encode_maxpool  (None, 80, 80, 64)   0           unet3plus_down1_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down2_conv_0 (Conv2D) (None, 80, 80, 128)  73856       unet3plus_down2_encode_maxpool[0]
# __________________________________________________________________________________________________
# unet3plus_down2_conv_0_activati (None, 80, 80, 128)  0           unet3plus_down2_conv_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down2_conv_1 (Conv2D) (None, 80, 80, 128)  147584      unet3plus_down2_conv_0_activation
# __________________________________________________________________________________________________
# unet3plus_down2_conv_1_activati (None, 80, 80, 128)  0           unet3plus_down2_conv_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down2_conv_2 (Conv2D) (None, 80, 80, 128)  147584      unet3plus_down2_conv_1_activation
# __________________________________________________________________________________________________
# unet3plus_down2_conv_2_activati (None, 80, 80, 128)  0           unet3plus_down2_conv_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down2_conv_3 (Conv2D) (None, 80, 80, 128)  147584      unet3plus_down2_conv_2_activation
# __________________________________________________________________________________________________
# unet3plus_down2_conv_3_activati (None, 80, 80, 128)  0           unet3plus_down2_conv_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_down3_encode_maxpool  (None, 40, 40, 128)  0           unet3plus_down2_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down3_conv_0 (Conv2D) (None, 40, 40, 256)  295168      unet3plus_down3_encode_maxpool[0]
# __________________________________________________________________________________________________
# unet3plus_down3_conv_0_activati (None, 40, 40, 256)  0           unet3plus_down3_conv_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down3_conv_1 (Conv2D) (None, 40, 40, 256)  590080      unet3plus_down3_conv_0_activation
# __________________________________________________________________________________________________
# unet3plus_down3_conv_1_activati (None, 40, 40, 256)  0           unet3plus_down3_conv_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down3_conv_2 (Conv2D) (None, 40, 40, 256)  590080      unet3plus_down3_conv_1_activation
# __________________________________________________________________________________________________
# unet3plus_down3_conv_2_activati (None, 40, 40, 256)  0           unet3plus_down3_conv_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down3_conv_3 (Conv2D) (None, 40, 40, 256)  590080      unet3plus_down3_conv_2_activation
# __________________________________________________________________________________________________
# unet3plus_down3_conv_3_activati (None, 40, 40, 256)  0           unet3plus_down3_conv_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_down4_encode_maxpool  (None, 20, 20, 256)  0           unet3plus_down3_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down4_conv_0 (Conv2D) (None, 20, 20, 512)  1180160     unet3plus_down4_encode_maxpool[0]
# __________________________________________________________________________________________________
# unet3plus_down4_conv_0_activati (None, 20, 20, 512)  0           unet3plus_down4_conv_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down4_conv_1 (Conv2D) (None, 20, 20, 512)  2359808     unet3plus_down4_conv_0_activation
# __________________________________________________________________________________________________
# unet3plus_down4_conv_1_activati (None, 20, 20, 512)  0           unet3plus_down4_conv_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down4_conv_2 (Conv2D) (None, 20, 20, 512)  2359808     unet3plus_down4_conv_1_activation
# __________________________________________________________________________________________________
# unet3plus_down4_conv_2_activati (None, 20, 20, 512)  0           unet3plus_down4_conv_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down4_conv_3 (Conv2D) (None, 20, 20, 512)  2359808     unet3plus_down4_conv_2_activation
# __________________________________________________________________________________________________
# unet3plus_down4_conv_3_activati (None, 20, 20, 512)  0           unet3plus_down4_conv_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_down5_encode_maxpool  (None, 10, 10, 512)  0           unet3plus_down4_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down5_conv_0 (Conv2D) (None, 10, 10, 1024) 4719616     unet3plus_down5_encode_maxpool[0]
# __________________________________________________________________________________________________
# unet3plus_down5_conv_0_activati (None, 10, 10, 1024) 0           unet3plus_down5_conv_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down5_conv_1 (Conv2D) (None, 10, 10, 1024) 9438208     unet3plus_down5_conv_0_activation
# __________________________________________________________________________________________________
# unet3plus_down5_conv_1_activati (None, 10, 10, 1024) 0           unet3plus_down5_conv_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_down5_conv_2 (Conv2D) (None, 10, 10, 1024) 9438208     unet3plus_down5_conv_1_activation
# __________________________________________________________________________________________________
# unet3plus_down5_conv_2_activati (None, 10, 10, 1024) 0           unet3plus_down5_conv_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_down5_conv_3 (Conv2D) (None, 10, 10, 1024) 9438208     unet3plus_down5_conv_2_activation
# __________________________________________________________________________________________________
# unet3plus_down5_conv_3_activati (None, 10, 10, 1024) 0           unet3plus_down5_conv_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_up_0_en0_unpool (UpSa (None, 20, 20, 1024) 0           unet3plus_down5_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_0_en2_maxpool (M (None, 20, 20, 256)  0           unet3plus_down3_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_0_en3_maxpool (M (None, 20, 20, 128)  0           unet3plus_down2_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_0_en4_maxpool (M (None, 20, 20, 64)   0           unet3plus_down1_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from0_to0_0 (Con (None, 20, 20, 32)   294944      unet3plus_up_0_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to1_0 (Con (None, 20, 20, 32)   147488      unet3plus_down4_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from0_to2_0 (Con (None, 20, 20, 32)   73760       unet3plus_down_0_en2_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from0_to3_0 (Con (None, 20, 20, 32)   36896       unet3plus_down_0_en3_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from0_to4_0 (Con (None, 20, 20, 32)   18464       unet3plus_down_0_en4_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from0_to0_0_acti (None, 20, 20, 32)   0           unet3plus_down_from0_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to1_0_acti (None, 20, 20, 32)   0           unet3plus_down_from0_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to2_0_acti (None, 20, 20, 32)   0           unet3plus_down_from0_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to3_0_acti (None, 20, 20, 32)   0           unet3plus_down_from0_to3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from0_to4_0_acti (None, 20, 20, 32)   0           unet3plus_down_from0_to4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_concat_0 (Concatenate (None, 20, 20, 160)  0           unet3plus_down_from0_to0_0_activa
#                                                                  unet3plus_down_from0_to1_0_activa
#                                                                  unet3plus_down_from0_to2_0_activa
#                                                                  unet3plus_down_from0_to3_0_activa
#                                                                  unet3plus_down_from0_to4_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0 (Conv (None, 20, 20, 192)  276480      unet3plus_concat_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0_bn (B (None, 20, 20, 192)  768         unet3plus_fusion_conv_0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_0_activ (None, 20, 20, 192)  0           unet3plus_fusion_conv_0_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_1 (Conv (None, 20, 20, 192)  331776      unet3plus_fusion_conv_0_0_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_1_bn (B (None, 20, 20, 192)  768         unet3plus_fusion_conv_0_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_1_activ (None, 20, 20, 192)  0           unet3plus_fusion_conv_0_1_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_2 (Conv (None, 20, 20, 192)  331776      unet3plus_fusion_conv_0_1_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_2_bn (B (None, 20, 20, 192)  768         unet3plus_fusion_conv_0_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_2_activ (None, 20, 20, 192)  0           unet3plus_fusion_conv_0_2_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_3 (Conv (None, 20, 20, 192)  331776      unet3plus_fusion_conv_0_2_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_3_bn (B (None, 20, 20, 192)  768         unet3plus_fusion_conv_0_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_0_3_activ (None, 20, 20, 192)  0           unet3plus_fusion_conv_0_3_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_1_en0_unpool (UpSa (None, 40, 40, 1024) 0           unet3plus_down5_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_up_1_en1_unpool (UpSa (None, 40, 40, 192)  0           unet3plus_fusion_conv_0_3_activat
# __________________________________________________________________________________________________
# unet3plus_down_1_en3_maxpool (M (None, 40, 40, 128)  0           unet3plus_down2_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_1_en4_maxpool (M (None, 40, 40, 64)   0           unet3plus_down1_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from1_to0_0 (Con (None, 40, 40, 32)   294944      unet3plus_up_1_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to1_0 (Con (None, 40, 40, 32)   55328       unet3plus_up_1_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to2_0 (Con (None, 40, 40, 32)   73760       unet3plus_down3_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from1_to3_0 (Con (None, 40, 40, 32)   36896       unet3plus_down_1_en3_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from1_to4_0 (Con (None, 40, 40, 32)   18464       unet3plus_down_1_en4_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from1_to0_0_acti (None, 40, 40, 32)   0           unet3plus_down_from1_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to1_0_acti (None, 40, 40, 32)   0           unet3plus_down_from1_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to2_0_acti (None, 40, 40, 32)   0           unet3plus_down_from1_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to3_0_acti (None, 40, 40, 32)   0           unet3plus_down_from1_to3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from1_to4_0_acti (None, 40, 40, 32)   0           unet3plus_down_from1_to4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_concat_1 (Concatenate (None, 40, 40, 160)  0           unet3plus_down_from1_to0_0_activa
#                                                                  unet3plus_down_from1_to1_0_activa
#                                                                  unet3plus_down_from1_to2_0_activa
#                                                                  unet3plus_down_from1_to3_0_activa
#                                                                  unet3plus_down_from1_to4_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0 (Conv (None, 40, 40, 192)  276480      unet3plus_concat_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0_bn (B (None, 40, 40, 192)  768         unet3plus_fusion_conv_1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_0_activ (None, 40, 40, 192)  0           unet3plus_fusion_conv_1_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_1 (Conv (None, 40, 40, 192)  331776      unet3plus_fusion_conv_1_0_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_1_bn (B (None, 40, 40, 192)  768         unet3plus_fusion_conv_1_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_1_activ (None, 40, 40, 192)  0           unet3plus_fusion_conv_1_1_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_2 (Conv (None, 40, 40, 192)  331776      unet3plus_fusion_conv_1_1_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_2_bn (B (None, 40, 40, 192)  768         unet3plus_fusion_conv_1_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_2_activ (None, 40, 40, 192)  0           unet3plus_fusion_conv_1_2_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_3 (Conv (None, 40, 40, 192)  331776      unet3plus_fusion_conv_1_2_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_3_bn (B (None, 40, 40, 192)  768         unet3plus_fusion_conv_1_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_1_3_activ (None, 40, 40, 192)  0           unet3plus_fusion_conv_1_3_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_2_en0_unpool (UpSa (None, 80, 80, 1024) 0           unet3plus_down5_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_up_2_en1_unpool (UpSa (None, 80, 80, 192)  0           unet3plus_fusion_conv_0_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_2_en2_unpool (UpSa (None, 80, 80, 192)  0           unet3plus_fusion_conv_1_3_activat
# __________________________________________________________________________________________________
# unet3plus_down_2_en4_maxpool (M (None, 80, 80, 64)   0           unet3plus_down1_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from2_to0_0 (Con (None, 80, 80, 32)   294944      unet3plus_up_2_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to1_0 (Con (None, 80, 80, 32)   55328       unet3plus_up_2_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to2_0 (Con (None, 80, 80, 32)   55328       unet3plus_up_2_en2_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to3_0 (Con (None, 80, 80, 32)   36896       unet3plus_down2_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from2_to4_0 (Con (None, 80, 80, 32)   18464       unet3plus_down_2_en4_maxpool[0][0
# __________________________________________________________________________________________________
# unet3plus_down_from2_to0_0_acti (None, 80, 80, 32)   0           unet3plus_down_from2_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to1_0_acti (None, 80, 80, 32)   0           unet3plus_down_from2_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to2_0_acti (None, 80, 80, 32)   0           unet3plus_down_from2_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to3_0_acti (None, 80, 80, 32)   0           unet3plus_down_from2_to3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from2_to4_0_acti (None, 80, 80, 32)   0           unet3plus_down_from2_to4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_concat_2 (Concatenate (None, 80, 80, 160)  0           unet3plus_down_from2_to0_0_activa
#                                                                  unet3plus_down_from2_to1_0_activa
#                                                                  unet3plus_down_from2_to2_0_activa
#                                                                  unet3plus_down_from2_to3_0_activa
#                                                                  unet3plus_down_from2_to4_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0 (Conv (None, 80, 80, 192)  276480      unet3plus_concat_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0_bn (B (None, 80, 80, 192)  768         unet3plus_fusion_conv_2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_0_activ (None, 80, 80, 192)  0           unet3plus_fusion_conv_2_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_1 (Conv (None, 80, 80, 192)  331776      unet3plus_fusion_conv_2_0_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_1_bn (B (None, 80, 80, 192)  768         unet3plus_fusion_conv_2_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_1_activ (None, 80, 80, 192)  0           unet3plus_fusion_conv_2_1_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_2 (Conv (None, 80, 80, 192)  331776      unet3plus_fusion_conv_2_1_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_2_bn (B (None, 80, 80, 192)  768         unet3plus_fusion_conv_2_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_2_activ (None, 80, 80, 192)  0           unet3plus_fusion_conv_2_2_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_3 (Conv (None, 80, 80, 192)  331776      unet3plus_fusion_conv_2_2_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_3_bn (B (None, 80, 80, 192)  768         unet3plus_fusion_conv_2_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_2_3_activ (None, 80, 80, 192)  0           unet3plus_fusion_conv_2_3_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_3_en0_unpool (UpSa (None, 160, 160, 102 0           unet3plus_down5_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_up_3_en1_unpool (UpSa (None, 160, 160, 192 0           unet3plus_fusion_conv_0_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_3_en2_unpool (UpSa (None, 160, 160, 192 0           unet3plus_fusion_conv_1_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_3_en3_unpool (UpSa (None, 160, 160, 192 0           unet3plus_fusion_conv_2_3_activat
# __________________________________________________________________________________________________
# unet3plus_down_from3_to0_0 (Con (None, 160, 160, 32) 294944      unet3plus_up_3_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to1_0 (Con (None, 160, 160, 32) 55328       unet3plus_up_3_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to2_0 (Con (None, 160, 160, 32) 55328       unet3plus_up_3_en2_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to3_0 (Con (None, 160, 160, 32) 55328       unet3plus_up_3_en3_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to4_0 (Con (None, 160, 160, 32) 18464       unet3plus_down1_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_down_from3_to0_0_acti (None, 160, 160, 32) 0           unet3plus_down_from3_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to1_0_acti (None, 160, 160, 32) 0           unet3plus_down_from3_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to2_0_acti (None, 160, 160, 32) 0           unet3plus_down_from3_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to3_0_acti (None, 160, 160, 32) 0           unet3plus_down_from3_to3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from3_to4_0_acti (None, 160, 160, 32) 0           unet3plus_down_from3_to4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_concat_3 (Concatenate (None, 160, 160, 160 0           unet3plus_down_from3_to0_0_activa
#                                                                  unet3plus_down_from3_to1_0_activa
#                                                                  unet3plus_down_from3_to2_0_activa
#                                                                  unet3plus_down_from3_to3_0_activa
#                                                                  unet3plus_down_from3_to4_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_0 (Conv (None, 160, 160, 192 276480      unet3plus_concat_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_0_bn (B (None, 160, 160, 192 768         unet3plus_fusion_conv_3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_0_activ (None, 160, 160, 192 0           unet3plus_fusion_conv_3_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_1 (Conv (None, 160, 160, 192 331776      unet3plus_fusion_conv_3_0_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_1_bn (B (None, 160, 160, 192 768         unet3plus_fusion_conv_3_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_1_activ (None, 160, 160, 192 0           unet3plus_fusion_conv_3_1_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_2 (Conv (None, 160, 160, 192 331776      unet3plus_fusion_conv_3_1_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_2_bn (B (None, 160, 160, 192 768         unet3plus_fusion_conv_3_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_2_activ (None, 160, 160, 192 0           unet3plus_fusion_conv_3_2_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_3 (Conv (None, 160, 160, 192 331776      unet3plus_fusion_conv_3_2_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_3_bn (B (None, 160, 160, 192 768         unet3plus_fusion_conv_3_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_3_3_activ (None, 160, 160, 192 0           unet3plus_fusion_conv_3_3_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_up_4_en0_unpool (UpSa (None, 320, 320, 102 0           unet3plus_down5_conv_3_activation
# __________________________________________________________________________________________________
# unet3plus_up_4_en1_unpool (UpSa (None, 320, 320, 192 0           unet3plus_fusion_conv_0_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_4_en2_unpool (UpSa (None, 320, 320, 192 0           unet3plus_fusion_conv_1_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_4_en3_unpool (UpSa (None, 320, 320, 192 0           unet3plus_fusion_conv_2_3_activat
# __________________________________________________________________________________________________
# unet3plus_up_4_en4_unpool (UpSa (None, 320, 320, 192 0           unet3plus_fusion_conv_3_3_activat
# __________________________________________________________________________________________________
# unet3plus_down_from4_to0_0 (Con (None, 320, 320, 32) 294944      unet3plus_up_4_en0_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to1_0 (Con (None, 320, 320, 32) 55328       unet3plus_up_4_en1_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to2_0 (Con (None, 320, 320, 32) 55328       unet3plus_up_4_en2_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to3_0 (Con (None, 320, 320, 32) 55328       unet3plus_up_4_en3_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to4_0 (Con (None, 320, 320, 32) 55328       unet3plus_up_4_en4_unpool[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to0_0_acti (None, 320, 320, 32) 0           unet3plus_down_from4_to0_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to1_0_acti (None, 320, 320, 32) 0           unet3plus_down_from4_to1_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to2_0_acti (None, 320, 320, 32) 0           unet3plus_down_from4_to2_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to3_0_acti (None, 320, 320, 32) 0           unet3plus_down_from4_to3_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_down_from4_to4_0_acti (None, 320, 320, 32) 0           unet3plus_down_from4_to4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_concat_4 (Concatenate (None, 320, 320, 160 0           unet3plus_down_from4_to0_0_activa
#                                                                  unet3plus_down_from4_to1_0_activa
#                                                                  unet3plus_down_from4_to2_0_activa
#                                                                  unet3plus_down_from4_to3_0_activa
#                                                                  unet3plus_down_from4_to4_0_activa
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_0 (Conv (None, 320, 320, 192 276480      unet3plus_concat_4[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_0_bn (B (None, 320, 320, 192 768         unet3plus_fusion_conv_4_0[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_0_activ (None, 320, 320, 192 0           unet3plus_fusion_conv_4_0_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_1 (Conv (None, 320, 320, 192 331776      unet3plus_fusion_conv_4_0_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_1_bn (B (None, 320, 320, 192 768         unet3plus_fusion_conv_4_1[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_1_activ (None, 320, 320, 192 0           unet3plus_fusion_conv_4_1_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_2 (Conv (None, 320, 320, 192 331776      unet3plus_fusion_conv_4_1_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_2_bn (B (None, 320, 320, 192 768         unet3plus_fusion_conv_4_2[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_2_activ (None, 320, 320, 192 0           unet3plus_fusion_conv_4_2_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_3 (Conv (None, 320, 320, 192 331776      unet3plus_fusion_conv_4_2_activat
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_3_bn (B (None, 320, 320, 192 768         unet3plus_fusion_conv_4_3[0][0]
# __________________________________________________________________________________________________
# unet3plus_fusion_conv_4_3_activ (None, 320, 320, 192 0           unet3plus_fusion_conv_4_3_bn[0][0
# __________________________________________________________________________________________________
# unet3plus_output_final (Conv2D) (None, 320, 320, 1)  1729        unet3plus_fusion_conv_4_3_activat
# __________________________________________________________________________________________________
# unet3plus_output_final_activati (None, 320, 320, 1)  0           unet3plus_output_final[0][0]
# ==================================================================================================
# Total params: 52,916,865
# Trainable params: 52,909,185
# Non-trainable params: 7,680
# __________________________________________________________________________________________________

# %%
# Original
# model = models.transunet_2d((320, 320, 1), filter_num=[32, 64, 128, 256, 512, 1024], n_labels=1, stack_num_down=2, stack_num_up=2, 
#                             embed_dim=384, num_mlp=1536, num_heads=8, num_transformer=8, activation='ReLU', mlp_activation='GELU', 
#                             output_activation='Sigmoid', name='transunet')

# Test 1
# model = models.transunet_2d((320, 320, 1), filter_num=[32, 64, 128, 256, 512], n_labels=1, stack_num_down=3, stack_num_up=3, 
#                             embed_dim=384, num_mlp=1536, num_heads=8, num_transformer=8, activation='ReLU', mlp_activation='GELU', 
#                             output_activation='Sigmoid', name='transunet')


# model = models.transunet_2d((320, 320, 1), filter_num=[32, 64, 128, 256, 512, 1024], n_labels=1, stack_num_down=3, stack_num_up=3, 
#                             embed_dim=384, num_mlp=1536, num_heads=10, num_transformer=10, activation='ReLU', mlp_activation='GELU', 
#                             output_activation='Sigmoid', name='transunet')


model = models.transunet_2d((320, 320, 1), filter_num=[32, 64, 128, 256, 512, 1024], n_labels=1, stack_num_down=2, stack_num_up=2, 
                            embed_dim=384, num_mlp=1536, num_heads=12, num_transformer=12, activation='ReLU', mlp_activation='GELU', 
                            output_activation='Sigmoid', name='transunet')

model.summary()
# Out:
# Model: "transunet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 320, 320, 1) 0
# __________________________________________________________________________________________________
# transunet_down0_0 (Conv2D)      (None, 320, 320, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# transunet_down0_0_activation (R (None, 320, 320, 32) 0           transunet_down0_0[0][0]
# __________________________________________________________________________________________________
# transunet_down0_1 (Conv2D)      (None, 320, 320, 32) 9248        transunet_down0_0_activation[0][0
# __________________________________________________________________________________________________
# transunet_down0_1_activation (R (None, 320, 320, 32) 0           transunet_down0_1[0][0]
# __________________________________________________________________________________________________
# transunet_down1_encode_maxpool  (None, 160, 160, 32) 0           transunet_down0_1_activation[0][0
# __________________________________________________________________________________________________
# transunet_down1_conv_0 (Conv2D) (None, 160, 160, 64) 18496       transunet_down1_encode_maxpool[0]
# __________________________________________________________________________________________________
# transunet_down1_conv_0_activati (None, 160, 160, 64) 0           transunet_down1_conv_0[0][0]
# __________________________________________________________________________________________________
# transunet_down1_conv_1 (Conv2D) (None, 160, 160, 64) 36928       transunet_down1_conv_0_activation
# __________________________________________________________________________________________________
# transunet_down1_conv_1_activati (None, 160, 160, 64) 0           transunet_down1_conv_1[0][0]
# __________________________________________________________________________________________________
# transunet_down2_encode_maxpool  (None, 80, 80, 64)   0           transunet_down1_conv_1_activation
# __________________________________________________________________________________________________
# transunet_down2_conv_0 (Conv2D) (None, 80, 80, 128)  73856       transunet_down2_encode_maxpool[0]
# __________________________________________________________________________________________________
# transunet_down2_conv_0_activati (None, 80, 80, 128)  0           transunet_down2_conv_0[0][0]
# __________________________________________________________________________________________________
# transunet_down2_conv_1 (Conv2D) (None, 80, 80, 128)  147584      transunet_down2_conv_0_activation
# __________________________________________________________________________________________________
# transunet_down2_conv_1_activati (None, 80, 80, 128)  0           transunet_down2_conv_1[0][0]
# __________________________________________________________________________________________________
# transunet_down3_encode_maxpool  (None, 40, 40, 128)  0           transunet_down2_conv_1_activation
# __________________________________________________________________________________________________
# transunet_down3_conv_0 (Conv2D) (None, 40, 40, 256)  295168      transunet_down3_encode_maxpool[0]
# __________________________________________________________________________________________________
# transunet_down3_conv_0_activati (None, 40, 40, 256)  0           transunet_down3_conv_0[0][0]
# __________________________________________________________________________________________________
# transunet_down3_conv_1 (Conv2D) (None, 40, 40, 256)  590080      transunet_down3_conv_0_activation
# __________________________________________________________________________________________________
# transunet_down3_conv_1_activati (None, 40, 40, 256)  0           transunet_down3_conv_1[0][0]
# __________________________________________________________________________________________________
# transunet_down4_encode_maxpool  (None, 20, 20, 256)  0           transunet_down3_conv_1_activation
# __________________________________________________________________________________________________
# transunet_down4_conv_0 (Conv2D) (None, 20, 20, 512)  1180160     transunet_down4_encode_maxpool[0]
# __________________________________________________________________________________________________
# transunet_down4_conv_0_activati (None, 20, 20, 512)  0           transunet_down4_conv_0[0][0]
# __________________________________________________________________________________________________
# transunet_down4_conv_1 (Conv2D) (None, 20, 20, 512)  2359808     transunet_down4_conv_0_activation
# __________________________________________________________________________________________________
# transunet_down4_conv_1_activati (None, 20, 20, 512)  0           transunet_down4_conv_1[0][0]
# __________________________________________________________________________________________________
# transunet_down5_encode_maxpool  (None, 10, 10, 512)  0           transunet_down4_conv_1_activation
# __________________________________________________________________________________________________
# transunet_down5_conv_0 (Conv2D) (None, 10, 10, 1024) 4719616     transunet_down5_encode_maxpool[0]
# __________________________________________________________________________________________________
# transunet_down5_conv_0_activati (None, 10, 10, 1024) 0           transunet_down5_conv_0[0][0]
# __________________________________________________________________________________________________
# transunet_down5_conv_1 (Conv2D) (None, 10, 10, 1024) 9438208     transunet_down5_conv_0_activation
# __________________________________________________________________________________________________
# transunet_down5_conv_1_activati (None, 10, 10, 1024) 0           transunet_down5_conv_1[0][0]
# __________________________________________________________________________________________________
# transunet_conv_trans_before (Co (None, 10, 10, 1024) 1048576     transunet_down5_conv_1_activation
# __________________________________________________________________________________________________
# patch_extract_1 (patch_extract) (None, 100, 1024)    0           transunet_conv_trans_before[0][0]
# __________________________________________________________________________________________________
# patch_embedding_1 (patch_embedd (None, 100, 384)     432000      patch_extract_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_layer_norm_1 (L (None, 100, 384)     768         patch_embedding_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_0_layer_norm_1[0][0
#                                                                  transunet_ViT_0_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_0_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_0_atten[0][0]
#                                                                  patch_embedding_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_0_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_0_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_0_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_0_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_0_mlp_activation_ (None, 100, 384)     0           transunet_ViT_0_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_0_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_0_mlp_activation_1[
#                                                                  transunet_ViT_0_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_0_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_1_layer_norm_1[0][0
#                                                                  transunet_ViT_1_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_1_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_1_atten[0][0]
#                                                                  transunet_ViT_0_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_1_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_1_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_1_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_1_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_1_mlp_activation_ (None, 100, 384)     0           transunet_ViT_1_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_1_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_1_mlp_activation_1[
#                                                                  transunet_ViT_1_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_1_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_2_layer_norm_1[0][0
#                                                                  transunet_ViT_2_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_2_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_2_atten[0][0]
#                                                                  transunet_ViT_1_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_2_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_2_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_2_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_2_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_2_mlp_activation_ (None, 100, 384)     0           transunet_ViT_2_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_2_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_2_mlp_activation_1[
#                                                                  transunet_ViT_2_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_2_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_3_layer_norm_1[0][0
#                                                                  transunet_ViT_3_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_3_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_3_atten[0][0]
#                                                                  transunet_ViT_2_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_3_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_3_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_3_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_3_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_3_mlp_activation_ (None, 100, 384)     0           transunet_ViT_3_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_3_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_3_mlp_activation_1[
#                                                                  transunet_ViT_3_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_3_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_4_layer_norm_1[0][0
#                                                                  transunet_ViT_4_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_4_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_4_atten[0][0]
#                                                                  transunet_ViT_3_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_4_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_4_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_4_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_4_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_4_mlp_activation_ (None, 100, 384)     0           transunet_ViT_4_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_4_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_4_mlp_activation_1[
#                                                                  transunet_ViT_4_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_4_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_5_layer_norm_1[0][0
#                                                                  transunet_ViT_5_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_5_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_5_atten[0][0]
#                                                                  transunet_ViT_4_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_5_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_5_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_5_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_5_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_5_mlp_activation_ (None, 100, 384)     0           transunet_ViT_5_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_5_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_5_mlp_activation_1[
#                                                                  transunet_ViT_5_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_5_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_6_layer_norm_1[0][0
#                                                                  transunet_ViT_6_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_6_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_6_atten[0][0]
#                                                                  transunet_ViT_5_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_6_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_6_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_6_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_6_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_6_mlp_activation_ (None, 100, 384)     0           transunet_ViT_6_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_6_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_6_mlp_activation_1[
#                                                                  transunet_ViT_6_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_6_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_7_layer_norm_1[0][0
#                                                                  transunet_ViT_7_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_7_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_7_atten[0][0]
#                                                                  transunet_ViT_6_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_7_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_7_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_7_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_7_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_7_mlp_activation_ (None, 100, 384)     0           transunet_ViT_7_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_7_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_7_mlp_activation_1[
#                                                                  transunet_ViT_7_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_7_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_8_layer_norm_1[0][0
#                                                                  transunet_ViT_8_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_8_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_8_atten[0][0]
#                                                                  transunet_ViT_7_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_8_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_8_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_8_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_8_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_8_mlp_activation_ (None, 100, 384)     0           transunet_ViT_8_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_8_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_8_mlp_activation_1[
#                                                                  transunet_ViT_8_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_layer_norm_1 (L (None, 100, 384)     768         transunet_ViT_8_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_atten (MultiHea (None, 100, 384)     7092096     transunet_ViT_9_layer_norm_1[0][0
#                                                                  transunet_ViT_9_layer_norm_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_9_skip_1 (Add)    (None, 100, 384)     0           transunet_ViT_9_atten[0][0]
#                                                                  transunet_ViT_8_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_layer_norm_2 (L (None, 100, 384)     768         transunet_ViT_9_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_dense_0 (De (None, 100, 1536)    591360      transunet_ViT_9_layer_norm_2[0][0
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_activation_ (None, 100, 1536)    0           transunet_ViT_9_mlp_dense_0[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_dense_1 (De (None, 100, 384)     590208      transunet_ViT_9_mlp_activation_0[
# __________________________________________________________________________________________________
# transunet_ViT_9_mlp_activation_ (None, 100, 384)     0           transunet_ViT_9_mlp_dense_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_9_skip_2 (Add)    (None, 100, 384)     0           transunet_ViT_9_mlp_activation_1[
#                                                                  transunet_ViT_9_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_layer_norm_1 ( (None, 100, 384)     768         transunet_ViT_9_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_atten (MultiHe (None, 100, 384)     7092096     transunet_ViT_10_layer_norm_1[0][
#                                                                  transunet_ViT_10_layer_norm_1[0][
# __________________________________________________________________________________________________
# transunet_ViT_10_skip_1 (Add)   (None, 100, 384)     0           transunet_ViT_10_atten[0][0]
#                                                                  transunet_ViT_9_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_layer_norm_2 ( (None, 100, 384)     768         transunet_ViT_10_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_dense_0 (D (None, 100, 1536)    591360      transunet_ViT_10_layer_norm_2[0][
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_activation (None, 100, 1536)    0           transunet_ViT_10_mlp_dense_0[0][0
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_dense_1 (D (None, 100, 384)     590208      transunet_ViT_10_mlp_activation_0
# __________________________________________________________________________________________________
# transunet_ViT_10_mlp_activation (None, 100, 384)     0           transunet_ViT_10_mlp_dense_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_10_skip_2 (Add)   (None, 100, 384)     0           transunet_ViT_10_mlp_activation_1
#                                                                  transunet_ViT_10_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_layer_norm_1 ( (None, 100, 384)     768         transunet_ViT_10_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_atten (MultiHe (None, 100, 384)     7092096     transunet_ViT_11_layer_norm_1[0][
#                                                                  transunet_ViT_11_layer_norm_1[0][
# __________________________________________________________________________________________________
# transunet_ViT_11_skip_1 (Add)   (None, 100, 384)     0           transunet_ViT_11_atten[0][0]
#                                                                  transunet_ViT_10_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_layer_norm_2 ( (None, 100, 384)     768         transunet_ViT_11_skip_1[0][0]
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_dense_0 (D (None, 100, 1536)    591360      transunet_ViT_11_layer_norm_2[0][
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_activation (None, 100, 1536)    0           transunet_ViT_11_mlp_dense_0[0][0
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_dense_1 (D (None, 100, 384)     590208      transunet_ViT_11_mlp_activation_0
# __________________________________________________________________________________________________
# transunet_ViT_11_mlp_activation (None, 100, 384)     0           transunet_ViT_11_mlp_dense_1[0][0
# __________________________________________________________________________________________________
# transunet_ViT_11_skip_2 (Add)   (None, 100, 384)     0           transunet_ViT_11_mlp_activation_1
#                                                                  transunet_ViT_11_skip_1[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 10, 10, 384)  0           transunet_ViT_11_skip_2[0][0]
# __________________________________________________________________________________________________
# transunet_conv_trans_after (Con (None, 10, 10, 1024) 393216      tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# transunet_up0_decode_unpool (Up (None, 20, 20, 1024) 0           transunet_conv_trans_after[0][0]
# __________________________________________________________________________________________________
# transunet_up0_conv_before_conca (None, 20, 20, 512)  4719104     transunet_up0_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up0_conv_before_conca (None, 20, 20, 512)  0           transunet_up0_conv_before_concat_
# __________________________________________________________________________________________________
# transunet_up0_concat (Concatena (None, 20, 20, 1024) 0           transunet_up0_conv_before_concat_
#                                                                  transunet_down4_conv_1_activation
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 20, 20, 512)  4719104     transunet_up0_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 20, 20, 512)  0           transunet_up0_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 20, 20, 512)  2359808     transunet_up0_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up0_conv_after_concat (None, 20, 20, 512)  0           transunet_up0_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up1_decode_unpool (Up (None, 40, 40, 512)  0           transunet_up0_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up1_conv_before_conca (None, 40, 40, 256)  1179904     transunet_up1_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up1_conv_before_conca (None, 40, 40, 256)  0           transunet_up1_conv_before_concat_
# __________________________________________________________________________________________________
# transunet_up1_concat (Concatena (None, 40, 40, 512)  0           transunet_up1_conv_before_concat_
#                                                                  transunet_down3_conv_1_activation
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 40, 40, 256)  1179904     transunet_up1_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 40, 40, 256)  0           transunet_up1_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 40, 40, 256)  590080      transunet_up1_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up1_conv_after_concat (None, 40, 40, 256)  0           transunet_up1_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up2_decode_unpool (Up (None, 80, 80, 256)  0           transunet_up1_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up2_conv_before_conca (None, 80, 80, 128)  295040      transunet_up2_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up2_conv_before_conca (None, 80, 80, 128)  0           transunet_up2_conv_before_concat_
# __________________________________________________________________________________________________
# transunet_up2_concat (Concatena (None, 80, 80, 256)  0           transunet_up2_conv_before_concat_
#                                                                  transunet_down2_conv_1_activation
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 80, 80, 128)  295040      transunet_up2_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 80, 80, 128)  0           transunet_up2_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 80, 80, 128)  147584      transunet_up2_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up2_conv_after_concat (None, 80, 80, 128)  0           transunet_up2_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up3_decode_unpool (Up (None, 160, 160, 128 0           transunet_up2_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up3_conv_before_conca (None, 160, 160, 64) 73792       transunet_up3_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up3_conv_before_conca (None, 160, 160, 64) 0           transunet_up3_conv_before_concat_
# __________________________________________________________________________________________________
# transunet_up3_concat (Concatena (None, 160, 160, 128 0           transunet_up3_conv_before_concat_
#                                                                  transunet_down1_conv_1_activation
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 160, 160, 64) 73792       transunet_up3_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 160, 160, 64) 0           transunet_up3_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 160, 160, 64) 36928       transunet_up3_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up3_conv_after_concat (None, 160, 160, 64) 0           transunet_up3_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up4_decode_unpool (Up (None, 320, 320, 64) 0           transunet_up3_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_up4_conv_before_conca (None, 320, 320, 32) 18464       transunet_up4_decode_unpool[0][0]
# __________________________________________________________________________________________________
# transunet_up4_conv_before_conca (None, 320, 320, 32) 0           transunet_up4_conv_before_concat_
# __________________________________________________________________________________________________
# transunet_up4_concat (Concatena (None, 320, 320, 64) 0           transunet_up4_conv_before_concat_
#                                                                  transunet_down0_1_activation[0][0
# __________________________________________________________________________________________________
# transunet_up4_conv_after_concat (None, 320, 320, 32) 18464       transunet_up4_concat[0][0]
# __________________________________________________________________________________________________
# transunet_up4_conv_after_concat (None, 320, 320, 32) 0           transunet_up4_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up4_conv_after_concat (None, 320, 320, 32) 9248        transunet_up4_conv_after_concat_0
# __________________________________________________________________________________________________
# transunet_up4_conv_after_concat (None, 320, 320, 32) 0           transunet_up4_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_output (Conv2D)       (None, 320, 320, 1)  33          transunet_up4_conv_after_concat_1
# __________________________________________________________________________________________________
# transunet_output_activation (Ac (None, 320, 320, 1)  0           transunet_output[0][0]
# ==================================================================================================
# Total params: 135,761,953
# Trainable params: 135,761,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# model = models.swin_unet_2d(input_size=image_input_shape, filter_num_begin=64, n_labels=1, depth=5, stack_num_down=2, stack_num_up=2, 
                                    # patch_size=(2,2), num_heads=[4, 8, 16, 16, 16], window_size=[4, 2, 2, 2, 2], num_mlp=768, output_activation='Sigmoid')

model = models.swin_unet_2d(input_size=(320,320,1), filter_num_begin=64, n_labels=1, depth=5, stack_num_down=3, stack_num_up=3, 
                                    patch_size=(8,8), num_heads=[8, 8, 8, 8, 8], window_size=[4, 4, 4, 4, 4], num_mlp=768, output_activation='Sigmoid')

model.summary()

# %%
# model = get_model('swin_unet_2d', image_input_shape, [32, 64, 128, 256, 512, 1024])
model.summary()
